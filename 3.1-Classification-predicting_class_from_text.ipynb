# %% [markdown]
# # Predicting number of stars from text (classification)

# %%
import pickle
from train_test_split import get_training_portion_of_the_data, train_test_split_as_requested
from model_evaluation import draw_word_cloud, test_different_models, metrics_classification, print_scoretable, draw_confusion_matrix_for_good_poor, create_graphs_from_scores, get_metrics_for_algorithm, add_or_replace_to_dataframe

import matplotlib.pyplot as plt

import numpy as np

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn.decomposition import PCA

CATEGORY_COLUMN_NAME = "category"
RANDOM_STATE = 42

# %% [markdown]
# ## Getting data from pickle files dumped in notebook 1

# %%
with open("random_reviews.p","rb") as f:
    random_reviews = pickle.load( f )

with open("bow1000.p","rb") as f:
    bow1000 = pickle.load( f )

# %% [markdown]
# ## Testing binary classification methods of scikit-learn
# Predict the label (good or poor) of a review based on the review text

# %%
random_reviews.head()
# Out:
#               business_id  cool                date  funny  \
# 0  KW5edXlPGeZ0cx7MiJyamw     0 2017-03-07 02:03:24      0
# 1  oxwGyA17NL6c5t1Etg5WgQ     0 2017-04-13 04:03:48      0
# 2  bKxKPGmkwH-Q-GSbt7chNA     1 2013-08-11 20:05:49      1
# 3  q5viyMO6EtJMmmarb4YmIA     0 2015-01-09 23:57:08      0
# 4  BS7PU7REvJZ7hVSHA6z8wQ     0 2017-09-03 22:40:45      0
#
#                 review_id  stars  \
# 0  nkvJghZnOkZy4HAo87ouSA      5
# 1  7KrKzKgUdflicfUs_bWNUQ      1
# 2  f54iEgnNZEE-JPcdVuNXSQ      2
# 3  AtKH9dzGHIKoyAhOLcVUIw      4
# 4  C5vaxaN3IZvmBpvcv0uYXw      2
#
#                                                 text  useful  \
# 0  A stellar cafe!!! Very classy, warm & inviting...       0
# 1  Can you say "Bait and Switch?"  A couple of da...       1
# 2  When first walking in to Stingray Sushi, a low...       3
# 3  A very beautiful restaurant in the Hardrock ca...       2
# 4  I've been here twice. The first time was a pre...       1
#
#                   user_id  category
# 0  PH2Ly-LUDc5i-eW_97MlNw         1
# 1  EnSUGj7a7FocW3blBj_hEw         0
# 2  aY4FqMsNXBirS72lM_CdwQ         0
# 3  CTaZ3ebFGQMHaLZhnO2EuA         1
# 4  Kya8CWymuq437rxhHyiM2g         0

# %% [markdown]
# ### Testing different algorithms for predicting category good-poor
# - simple Logistic Regression is on par with Multilayer Perceptron based classifier and Random Forest classifier
# - learning curve of Random Forest classifier shows the model would benefit from more data (cross-validation score is increasing)

# %%
X = np.array(bow1000)
y = np.array(random_reviews[CATEGORY_COLUMN_NAME])

X_train, X_test, y_train, y_test = train_test_split_as_requested(X, y)
# print("X_train.shape: {}, y_train.shape: {}".format(X_train.shape, y_train.shape))

modelsToTest=[
  ("LogisticRegression", sklearn.linear_model.LogisticRegression(solver='lbfgs', random_state=RANDOM_STATE, max_iter=1000)), #, multi_class='multinomial'
  ("LinearRegression", sklearn.linear_model.LinearRegression(normalize=True, fit_intercept=True), 0.5),
  ("Ridge", sklearn.linear_model.Ridge(alpha=.5, fit_intercept=False), 0.5),
  ("Perceptron", sklearn.linear_model.Perceptron()),
  ("KNeighborsClassifier", KNeighborsClassifier(n_neighbors=2,n_jobs=10,leaf_size=40, algorithm ="brute")),
  ("GaussianProcessClassifier", GaussianProcessClassifier(1.0 * RBF(1.0))),
  ("DecisionTreeClassifier", DecisionTreeClassifier(max_depth=5)),
  ("MLPClassifier", MLPClassifier(alpha=1, max_iter=1000)),
  ("AdaBoostClassifier", AdaBoostClassifier()),
  ("QuadraticDiscriminantAnalysis", QuadraticDiscriminantAnalysis()),
  ("SVC", SVC(gamma='auto')),
  ("RandomForestClassifier",RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False))
]
predictionTable = test_different_models(X_train, X_test, y_train, y_test, modelsToTest)
# Out:
# 8% (1 of 12) |##                       | Elapsed Time: 0:00:00 ETA:   0:00:01Returns X_train, X_test, y_train, y_test
#  66% (8 of 12) |################         | Elapsed Time: 0:00:19 ETA:   0:00:07C:\Users\MattiH\.conda\envs\DS_project\lib\site-packages\sklearn\discriminant_analysis.py:693: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\MattiH\.conda\envs\DS_project\lib\site-packages\sklearn\discriminant_analysis.py:693: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# 100% (12 of 12) |########################| Elapsed Time: 0:00:20 Time:  0:00:20

# %%
scores = metrics_classification(predictionTable)
scores = scores.sort_values(by=['Accuracy'], ascending=False)
print_scoretable(scores)
# Out:
# <style  type="text/css" >
#     #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow0_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 98.3%, transparent 98.3%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 89.9%, transparent 89.9%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 80.8%, transparent 80.8%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow1_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 98.5%, transparent 98.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 97.0%, transparent 97.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 98.2%, transparent 98.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 89.4%, transparent 89.4%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 79.5%, transparent 79.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow2_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 98.5%, transparent 98.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 94.8%, transparent 94.8%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 97.8%, transparent 97.8%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 85.2%, transparent 85.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 82.2%, transparent 82.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow3_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 97.1%, transparent 97.1%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 96.8%, transparent 96.8%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 96.8%, transparent 96.8%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 91.0%, transparent 91.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 76.7%, transparent 76.7%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow4_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 95.6%, transparent 95.6%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 97.1%, transparent 97.1%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 69.9%, transparent 69.9%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow5_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 88.2%, transparent 88.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 83.5%, transparent 83.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 84.8%, transparent 84.8%);
#             width:  8em;
#             text-align:  center;
#         }    #T_3ef144ae_e2b9_11ea_b10a_d43b042194bcrow5_col4 {
#             width:  10em;
#              height:  80%;
#             ba

# %%
predictionTable_temp = test_different_models(X_train, X_test, y_train, y_test, modelsToTest[11:12], show_learning_curve=True)
draw_confusion_matrix_for_good_poor(y_test.flatten(), predictionTable_temp[modelsToTest[11:12][0][0]], title=modelsToTest[11:12][0][0])
# Out:
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00

# %% [markdown]
# ### Same tests after running PCA
# - lower Matthews Correlation Coefficient (MCC) for the best models, PCA doesn't help
# - given that there are more good reviews than bad, best to look at MCC as other measures look only at other class being predicted

# %%
y_train, y_test = y_train.reshape(-1,1), y_test.reshape(-1,1)
y_train = np.array(y_train)
y_test = np.array(y_test)

# Scaling data
scaler_X, scaler_y = StandardScaler(), StandardScaler()
scaler_X.fit(X_train), scaler_y.fit(y_train)
X_train_scaled, y_train_scaled = scaler_X.transform(X_train), scaler_y.transform(y_train)
X_test_scaled, y_test_scaled = scaler_X.transform(X_test), scaler_y.transform(y_test)

pca = PCA(0.5)
pca.fit(X_train_scaled)

# Plotting how large part of variance explained
explained = pca.explained_variance_ratio_.cumsum()

plt.plot(np.arange(len(explained)),explained)
plt.ylabel("Variance explained")
plt.xlabel("Number of PCA components")
plt.show()

X_train_pca, X_test_pca = pca.transform(X_train_scaled), pca.transform(X_test_scaled)
X_train_pca = np.array(X_train_pca)
X_test_pca = np.array(X_test_pca)

predictionTable = test_different_models(X_train_pca, X_test_pca, y_train.flatten(), y_test.flatten(), modelsToTest)
scoresPCA = metrics_classification(predictionTable)
scoresPCA = scoresPCA.sort_values(by=['Accuracy'], ascending=False)
print_scoretable(scoresPCA)
# Out:
# 100% (12 of 12) |########################| Elapsed Time: 0:00:05 Time:  0:00:05
# C:\Users\MattiH\.conda\envs\DS_project\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# <style  type="text/css" >
#     #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow0_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 86.2%, transparent 86.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow1_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 91.2%, transparent 91.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 79.6%, transparent 79.6%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 82.4%, transparent 82.4%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 94.3%, transparent 94.3%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 86.2%, transparent 86.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow2_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 89.0%, transparent 89.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 61.6%, transparent 61.6%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 76.6%, transparent 76.6%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 88.5%, transparent 88.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 94.6%, transparent 94.6%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow3_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 87.9%, transparent 87.9%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 56.8%, transparent 56.8%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 75.0%, transparent 75.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 87.3%, transparent 87.3%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 96.2%, transparent 96.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow4_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 82.4%, transparent 82.4%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 46.4%, transparent 46.4%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 62.2%, transparent 62.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 85.4%, transparent 85.4%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 94.6%, transparent 94.6%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow5_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 80.2%, transparent 80.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 58.9%, transparent 58.9%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 61.6%, transparent 61.6%);
#             width:  8em;
#             text-align:  center;
#         }    #T_46266d0a_e2b9_11ea_914c_d43b042194bcrow5_col4 {
#             width:  10em;
#              height:  80%;
#             ba

# %% [markdown]
# ### Adding baseline: all rated "good"

# %%
newSeries = get_metrics_for_algorithm("-- All reviews graded good --", np.ones(len(y_test)) , y_test)
scores = add_or_replace_to_dataframe(newSeries.Model, scores, newSeries)
scores = scores.sort_values(by=['Accuracy'], ascending=False)
# print_scoretable(scores)

# %%
draw_confusion_matrix_for_good_poor(y_test.flatten(),np.ones(len(y_test)), title="All reviews graded good")

# %% [markdown]
# ### Adding baseline: random guess

# %%
randomchoises = np.random.choice(a=[False, True], size=len(y_test))
newSeries = get_metrics_for_algorithm("-- Random guess --", randomchoises, y_test)
scores = add_or_replace_to_dataframe(newSeries.Model, scores, newSeries)
scores = scores.sort_values(by=['Accuracy'], ascending=False)

# %%
draw_confusion_matrix_for_good_poor(y_test.flatten(), randomchoises, title="Random guess")

# %% [markdown]
# ## All results as a table and graph
# - machine learning methods clearly outperform baselines in all measures

# %%
print_scoretable(scores)
# Out:
# <style  type="text/css" >
#     #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow0_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 98.5%, transparent 98.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 69.5%, transparent 69.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 80.8%, transparent 80.8%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow1_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 98.7%, transparent 98.7%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 97.4%, transparent 97.4%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 98.5%, transparent 98.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 69.3%, transparent 69.3%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 79.5%, transparent 79.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow2_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 98.7%, transparent 98.7%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 95.5%, transparent 95.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 98.1%, transparent 98.1%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 67.6%, transparent 67.6%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 82.2%, transparent 82.2%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow3_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 97.3%, transparent 97.3%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 97.3%, transparent 97.3%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 97.3%, transparent 97.3%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 69.9%, transparent 69.9%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 76.7%, transparent 76.7%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow4_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 96.0%, transparent 96.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 100.0%, transparent 100.0%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 97.5%, transparent 97.5%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 73.4%, transparent 73.4%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 69.9%, transparent 69.9%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow5_col0 {
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 89.3%, transparent 89.3%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 85.6%, transparent 85.6%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ddd 86.9%, transparent 86.9%);
#             width:  8em;
#             text-align:  center;
#         }    #T_467c5806_e2b9_11ea_9db0_d43b042194bcrow5_col4 {
#             width:  10em;
#              height:  80%;
#             back

# %%
create_graphs_from_scores(scores, modelsToTest)

# %%
predictionTable.T.style.apply(lambda x: ["background: lightgreen" if v == x.iloc[0] else "" for v in x], axis = 0)
# Out:
# <style  type="text/css" >
#     #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col0 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col1 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col2 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col3 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col4 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col5 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col6 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col7 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col8 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col9 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col10 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col11 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col12 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col13 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col14 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col15 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col16 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col17 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col18 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col19 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col20 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col21 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col22 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col23 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col24 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col25 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col26 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col27 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col28 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col29 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col30 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col31 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col32 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col33 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col34 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col35 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col36 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col37 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col38 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col39 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col40 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col41 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col42 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col43 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col44 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col45 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col46 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col47 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col48 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col49 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col50 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col51 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col52 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col53 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col54 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col55 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col56 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col57 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col58 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col59 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col60 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col61 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col62 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col63 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col64 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col65 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col66 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col67 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col68 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col69 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col70 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col71 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col72 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col73 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col74 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col75 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col76 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b980_d43b042194bcrow0_col77 {
#             background:  lightgreen;
#         }    #T_47ae7618_e2b9_11ea_b9
